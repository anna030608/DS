# %% [markdown]
# ### 시험점수 관리하기
#
# <aside>
# 💡
#
# 학생들이 국어, 영어, 수학, 사회, 과학의 5 과목에 대해서 시험을 치렀습니다.
#
# 학생의 이름과 각 과목의 성적을 입력 받아 관리하는 프로그램을 만들어봅시다.
#
# </aside>
#
# - 조건
#     - 국어, 영어, 수학, 사회, 과학 점수를 사용자에게 입력 받습니다.
#     - 최저 점수의 과목과 최고 점수의 과목, 그리고 5 과목의 평균 점수를 출력합니다.
#
#
# 예시
#
# 성적을 입력하세요. (국어 영어 수학 사회 과학):
# ->76 88 62 94 78
#
# 최저 점수: 수학
# 최고 점수: 사회
# 평균 점수: 79.6

# %%
subject = ["국어", "영어", "수학", "사회", "과학"]
dic = dict()

n = int(input("입력할 학생 수를 입력하시오: "))

for _ in range(n):
    name = input("이름을 입력하시오: ")
    score = list(map(int, input("점수를 입력하시오(공백 기준): ").split()))
    
    dic[name] = score  # {'이가현': [10, 10, 20, 30, 40]}
# Out:
# 입력할 학생 수를 입력하시오: 3
# 이름을 입력하시오: 이가현
# 점수를 입력하시오(공백 기준): 10 20 30 40 50
# 이름을 입력하시오: 성찬
# 점수를 입력하시오(공백 기준): 20 30 40 50 60
# 이름을 입력하시오: 쇼타로
# 점수를 입력하시오(공백 기준): 60 70 80 90 100

# %%
# 최저/최고/평균 점수를 알고 싶은 학생 이름 입력받기...
name = input("점수를 알고 싶은 학생 이름을 입력하시오: ")
score = dic[name]

# 비교를 위한 최저 / 최고 점수 설정.
min_score = 100
max_score = 0
mean_score = 0

min_idx = 0
max_idx = 0

for i in range(5):
    s = score[i]
    mean_score += s
    
    if s <= min_score:
        min_score = s
        min_idx = i
    elif s >= max_score:
        max_score = s
        max_idx = i
    
mean_score /= 5

print("최저 점수: ", subject[min_idx])
print("최고 점수: ", subject[max_idx])
print("평균 점수: ", mean_score)
# Out:
# 점수를 알고 싶은 학생 이름을 입력하시오: 이가현
# 최저 점수:  국어
# 최고 점수:  과학
# 평균 점수:  30.0
